# %%
from datetime import datetime, date, time
from pandas import DataFrame, read_csv
import pandas as pd
import numpy as np
from pandas_datareader import data, wb
import matplotlib.pyplot as plt
# %matplotlib inline
#from ggplot import *

# %%
weather = pd.read_csv('weather_data_new.csv', parse_dates=['date'])
trip = pd.read_csv('trip_data_new.csv',parse_dates=['date'])

# %%
super_muying = pd.merge(weather, trip, left_on='date', right_on='date')

# %%
super_muying.head(1)
# Out:
#         date  max_temp  mean_temp  min_temp  max_dp  mean_dp  min_dp  max_hum  \
# 0 2013-09-01      74.0       66.0      58.0    60.0     56.0    53.0     87.0
#
#    mean_hum  min_hum   ...        end_station  end_id  bike_num  user_type  \
# 0      68.0     49.0   ...    Beale at Market      56       506   Customer
#
#    season_y     start_city       end_city  month_y  year_y   day_y
# 0    Autumn  San Francisco  San Francisco        9    2013  Sunday
#
# [1 rows x 45 columns]

# %%
super_muying.info() # SO POWERFUL!!!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3339285 entries, 0 to 3339284
# Data columns (total 45 columns):
# date                datetime64[ns]
# max_temp            float64
# mean_temp           float64
# min_temp            float64
# max_dp              float64
# mean_dp             float64
# min_dp              float64
# max_hum             float64
# mean_hum            float64
# min_hum             float64
# max_sea             float64
# mean_sea            float64
# min_sea             float64
# max_vis             float64
# mean_vis            float64
# min_vis             float64
# max_wind            float64
# mean_wind           float64
# max_gust            float64
# rain_inches         float64
# cloud_cover         float64
# wind_dir_degrees    float64
# ZIP                 int64
# season_x            object
# city                object
# month_x             int64
# year_x              int64
# day_x               object
# Unnamed: 0          object
# ...

# %%
# ENDLESS POWER!!!
super_muying_ultra = super_muying.transpose()
super_muying_ultra
# Out:
#                                               0        \
# date                              2013-09-01 00:00:00
# max_temp                                           74
# mean_temp                                          66
# min_temp                                           58
# max_dp                                             60
# mean_dp                                            56
# min_dp                                             53
# max_hum                                            87
# mean_hum                                           68
# min_hum                                            49
# max_sea                                         29.96
# mean_sea                                        29.93
# min_sea                                         29.91
# max_vis                                            10
# mean_vis                                           10
# min_vis                                            10
# ...
