# %% [markdown]
# # babs_2016

# %%
import json
import pandas as pd
import numpy as np

# %%
babs = pd.read_json('json.json')

# %%
babs
# Out:
#               executionTime                                    stationBeanList
# 0   2016-08-10 11:29:01\nAM  {'stationName': 'San Jose Diridon Caltrain
# Sta...
# 1   2016-08-10 11:29:01\nAM  {'stationName': 'San Jose
# Civic
# Center', 'long...
# 2   2016-08-10 11:29:01\nAM  {'stationName': 'Santa
# Clara at
# Almaden', 'lon...
# 3   2016-08-10 11:29:01\nAM  {'stationName': 'Adobe on
# Almaden', 'longitude...
# 4   2016-08-10 11:29:01\nAM  {'stationName': 'San Pedro
# Square', 'longitude...
# 5   2016-08-10 11:29:01\nAM  {'stationName': 'Paseo de
# San
# Antonio', 'longi...
# 6   2016-08-10 11:29:01\nAM  {'stationName': 'San
# Salvador at
# 1st', 'longit...
# 7   2016-08-10 11:29:01\nAM  {'stationName': 'Japantown', 'longitude': -121...
# 8   2016-08-10 11:29:01\nAM  {'stationName': 'San Jose
# City
# Hall', 'longitu...
# 9   2016-08-10 11:29:01\nAM  {'stationName': 'MLK
# Library', 'longitude': -1...
# 10  2016-08-10 11:29:01\nAM  {'stationName': 'SJSU 4th
# at San
# ...
